# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a510g5/B15_PDS_10g5/blob/main/lab_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("world_population.csv")

plt.figure(figsize=(8,5))
plt.plot(data["Year"], data["Population"], marker="o", linestyle="-", color="blue")

plt.xlabel("Year")
plt.ylabel("Population (in billions)")
plt.title("World Population Growth Over Years")
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("AAPL.csv")
data["Date"] = pd.to_datetime(data["Date"])

plt.figure(figsize=(10,5))
plt.plot(data["Date"], data["Close"], color="green", linewidth=2)

plt.xlabel("Date")
plt.ylabel("Close Price (USD)")
plt.title("Apple Stock Price Trend")
plt.grid(True)
plt.tight_layout()
plt.show()
